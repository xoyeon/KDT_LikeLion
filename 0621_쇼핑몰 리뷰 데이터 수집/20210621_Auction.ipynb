# %%
# -*- coding: utf-8 -*-
## 여성의류 검색 단어
## url = "http://browse.auction.co.kr/search?keyword=%EC%97%AC%EC%84%B1%EC%9D%98%EB%A5%98&itemno=&nickname=&encKeyword=%25EC%2597%25AC%25EC%2584%25B1%25EC%259D%2598%25EB%25A5%2598&arraycategory=&frm=&dom=auction&isSuggestion=No&retry="
## url = "http://browse.auction.co.kr/search?keyword=%ED%99%94%EC%9E%A5%ED%92%88&itemno=&nickname=&encKeyword=%25ED%2599%2594%25EC%259E%25A5%25ED%2592%2588&arraycategory=&frm=&dom=auction&isSuggestion=No&retry="

## computer
## http://browse.auction.co.kr/search?keyword=computer&itemno=&nickname=&encKeyword=computer&arraycategory=&frm=&dom=auction&isSuggestion=No&retry=

# %%
import requests as rq
from bs4 import BeautifulSoup
import lxml

# %%
#%% utf-8로 인코딩
url = "http://browse.auction.co.kr/search?keyword={}&itemno=&nickname=&encKeyword={}&arraycategory=&frm=&dom=auction&isSuggestion=No&retry=".format("여성의류", "여성의류")
url
# Out:
# 'http://browse.auction.co.kr/search?keyword=여성의류&itemno=&nickname=&encKeyword=여성의류&arraycategory=&frm=&dom=auction&isSuggestion=No&retry='

# %%
res = rq.get(url)
res.url
html = res.content
soup = BeautifulSoup(html, 'lxml')

# %%
#%% 타이틀 가져오기 
soup_item = soup.find_all("div", class_="section--itemcard")
soup_item[1]
num = len(soup_item)
num
# Out:
# 100

# %%
title = []
price_sales = []
price_ori = []
company = []
for i in range(0, num):
    # 상품명
    soup_title = soup_item[i].find("span", class_="text--title")
    print(soup_title)
    if soup_title is not None:
        title_txt = soup_title.text
        title.append(title_txt)
    else:
        title.append("")
    
    # 상품가격(할인적용금액)
    soup_price = soup_item[i].find("strong", class_="text--price_seller")
    print(soup_price)
    if soup_price is not None:
        price_txt = soup_price.text
        price_sales.append(price_txt)
    else:
        price_sales.append("")
    
    # 상품가격(원래 금액)
    soup_price_ori = soup_item[i].find("strong", class_="text--price_original")
    print(soup_price_ori)
    if soup_price_ori is not None:
        price_ori_txt = soup_price_ori.text
        price_ori.append(price_ori_txt)   
    else:
        price_ori.append("")

    # 회사
    soup_company = soup_item[i].find("span", class_="text")
    print(soup_company)
    if soup_company is not None:
        soup_company_txt = soup_company.text
        company.append(soup_company_txt)   
    else:
        company.append("스마일배송")
        
        
    # 판매자
    #soup_company = soup_item[i].find("span", class_="text")
    #print(soup_company)
# Out:
# <span class="text--title">다온샵 신상 15%쿠폰 빅사이즈/데님/슬랙스/반바지<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">다온샵.</span>
# <span class="text--title">달리샵 여름신상 베스트 티셔츠/원피스/팬츠/스커트<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">달리샵1</span>
# <span class="text--title">15%쿠폰/여름빅세일/2장이상구입시 팬티사은품/무배<!-- --> </span>
# <strong class="text--price_seller">8,900</strong>
# <strong class="text--price_original">22,300</strong>
# <span class="text">factiomall</span>
# <span class="text--title">김여사봄신상 베스트 베이직 티셔츠/팬츠 균일가 20종<!-- --> </span>
# <strong class="text--price_seller">16,050</strong>
# <strong class="text--price_original">16,900</strong>
# <span class="text">김여사샵</span>
# <span class="text--title">16수 오버핏 남성 여성 반팔 무지 티셔츠 빅사이즈<!-- --> </span>
# <strong class="text--price_seller">10,900</strong>
# <strong class="text--price_original">36,300</strong>
# <span class="text">로드스타-루키스</span>
# <span class="text--title">15%쿠폰 데이뮤즈 원피스/자켓/가디건/바지/블라우스<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">데이뮤즈</span>
# <span class="text--title">달리샵 여름신상 빅사이즈 베스트 티셔츠/원피스/팬츠<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">달리샵1</span>
# <span class="text--title">15%할인쿠폰 마르조 오나라pick 썸머 페스티벌~<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">제이에프글로벌</span>
# <span class="text--title">EnC 봄여름 블라우스/원피스/팬츠 외 최대25%쿠폰<!-- --> </span>
# <strong class="text--price_seller">29,000</strong>
# <strong class="text--price_original">96,660</strong>
# <span class="text">EnC(이앤씨)</span>
# <span class="text--title">단아하고 여성스러운 플라워 자수 블라우스<!-- --> </span>
# <strong class="text--price_seller">27,040</strong>
# <strong class="text--price_original">29,400</strong>
# <span class="text">sellerbay1</span>
# <span class="text--title">티탁 15%쿠폰 특가/세트/맨투맨/원피스/롱티셔츠<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">주식회사티탁</span>
# <span class="text--title">여름 오픈특가 블라우스/원피스/티셔츠외<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">able.h</span>
# <span class="text--title">전국민15%쿠폰 여름NEW 빅사이즈/롱원피스/데님/4XL~<!-- --> </span>
# <strong class="text--price_seller">17,400</strong>
# <strong class="text--price_original">58,000</strong>
# <span class="text">스웨덴세탁소-</span>
# <span class="text--title"> 헬리꽁땡  로즈 원피스<!-- --> </span>
# <strong class="text--price_seller">49,800</strong>
# None
# <span class="text">롯데홈쇼핑</span>
# <span class="text--title">여름 최신 핫 트렌드 신상템 특가<!-- --> </span>
# <strong class="text--price_seller">19,900</strong>
# <strong class="text--price_original">66,300</strong>
# <span class="text">able.h</span>
# <span class="text--title">15%쿠폰/데이데이 여름신상 블라우스/원피스/팬츠<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">dayday-데이데이</span>
# <span class="text--title">패션페스타20% 여성 반팔티셔츠 여자 빅사이즈 티셔츠<!-- --> </span>
# <strong class="text--price_seller">7,900</strong>
# None
# <span class="text">사라걸스</span>
# <span class="text--title">(색상 검정) 비비안 유발타아즈50D/여성용/숙녀/무지<!-- --> </span>
# <strong class="text--price_seller">8,490</strong>
# None
# <span class="text">엑스포할인몰</span>
# <span class="text--title">빅사이즈 라운드 골지 티셔츠 니트느낌 오버핏 5XL까지<!-- --> </span>
# <strong class="text--price_seller">14,900</strong>
# None
# <span class="text">위러쉬</span>
# <span class="text--title"> TAG ME 태그미 플리츠 셋업 3종 세트<!-- --> </span>
# <strong class="text--price_seller">38,900</strong>
# <strong class="text--price_original">39,900</strong>
# <span class="text">최우수판매자</span>
# <span class="text--title">15% 쿠폰/데이데이 여름신상 블라우스/티셔츠/원피스<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">dayday-데이데이</span>
# <span class="text--title">드고떼 코튼 100 티블라우스 4종<!-- --> </span>
# <strong class="text--price_seller">29,900</strong>
# None
# <span class="text">최우수판매자</span>
# <span class="text--title"> Humming 허밍by 현영  린넨 블랜디드 셔츠형 블라우스 3종<!-- --> </span>
# <strong class="text--price_seller">49,000</strong>
# None
# <span class="text">최우수판매자</span>
# <span class="text--title">오리지날리 라운지웨어 원피스 2종<!-- --> </span>
# <strong class="text--price_seller">39,900</strong>
# None
# <span class="text">최우수판매자</span>
# <span class="text--title"> 런칭가 79000원  크레송CRESSON 21S/S 아트웍 블라우스 2종<!-- --> </span>
# <strong class="text--price_seller">59,000</strong>
# None
# <span class="text">최우수판매자</span>
# <span class="text--title">드고떼 코튼 100 티블라우스 4종 + 4종<!-- --> </span>
# <strong class="text--price_seller">39,900</strong>
# None
# <span class="text">최우수판매자</span>
# <span class="text--title">골지 핀턱 노와이어 브라탑 밴딩 브라렛<!-- --> </span>
# <strong class="text--price_seller">5,000</strong>
# None
# None
# <span class="text--title">골지 레이스 브라 팬티 세트<!-- --> </span>
# <strong class="text--price_seller">10,000</strong>
# None
# None
# <span class="text--title">요가 스포츠 노와이어 브라렛<!-- --> </span>
# <strong class="text--price_seller">5,000</strong>
# None
# None
# <span class="text--title">디즈니 아이스 쿨바지 V21 남성/여성/커플/조거팬츠<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# None
# None
# <span class="text--title">디즈니 쿨 반팔세트 V21 남성/여성/커플/잠옷/홈웨어<!-- --> </span>
# <strong class="text--price_seller">14,900</strong>
# None
# None
# <span class="text--title">네모 팬티 사각 심리스 노라인 슬림 누디 자체제작<!-- --> </span>
# <strong class="text--price_seller">5,900</strong>
# None
# None
# <span class="text--title">15%쿠폰할인 메이시스 여름 루즈핏 원피스 블라우스<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">메이시스1</span>
# <span class="text--title">수맘 여름 신상입고 15%쿠폰 면 홈웨어 잠옷 세트<!-- --> </span>
# <strong class="text--price_seller">5,900</strong>
# <strong class="text--price_original">19,600</strong>
# <span class="text">(수맘)</span>
# <span class="text--title">시크루즈/15%/단하루/티셔츠/박스티/팬츠/빅사이즈<!-- --> </span>
# <strong class="text--price_seller">6,900</strong>
# <strong class="text--price_original">23,000</strong>
# <span class="text">시크루즈</span>
# <span class="text--title">런닝 2500원/남자/남성/여자/여성/아동/쿨/조끼/인견<!-- --> </span>
# <strong class="text--price_seller">2,900</strong>
# <strong class="text--price_original">9,600</strong>
# <span class="text">한스속옷</span>
# <span class="text--title">엄마옷로즈맘 여름신상60종 인견 5060중년여성의류<!-- --> </span>
# <strong class="text--price_seller">12,900</strong>
# <strong class="text--price_original">43,000</strong>
# <span class="text">엄마옷로즈맘</span>
# <span class="text--title">15%쿠폰 반팔티 운동복 티셔츠 롱티 원피스 빅사이즈<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">뷰티플러스1168</span>
# <span class="text--title">15%중복쿠폰/쿨레깅스/쿨팬츠/원피스/7부/빅사이즈4XL<!-- --> </span>
# <strong class="text--price_seller">6,900</strong>
# <strong class="text--price_original">23,000</strong>
# <span class="text">VIVIDGLAM_</span>
# <span class="text--title">(15%쿠폰)애플힙 쿨링팬츠 빅사이즈 4XL 슬랙스/8부<!-- --> </span>
# <strong class="text--price_seller">6,900</strong>
# <strong class="text--price_original">22,900</strong>
# <span class="text">애플힙20</span>
# <span class="text--title">15%쿠폰 루즈델리 여름신상 롱원피스/빅사이즈/루즈핏<!-- --> </span>
# <strong class="text--price_seller">12,900</strong>
# <strong class="text--price_original">43,000</strong>
# <span class="text">루즈델리</span>
# <span class="text--title">모노시크/15%/티셔츠/신상/데일리/루즈핏/빅사이즈/<!-- --> </span>
# <strong class="text--price_seller">7,900</strong>
# <strong class="text--price_original">26,300</strong>
# <span class="text">monochic01</span>
# <span class="text--title">15%쿠폰가/XXL까지/빅사이즈/하객룩원피스<!-- --> </span>
# <strong class="text--price_seller">29,800</strong>
# <strong class="text--price_original">99,300</strong>
# <span class="text">시크라인</span>
# <span class="text--title">15%쿠폰 데이뮤즈 원피스/자켓/가디건/바지/블라우스<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">데이뮤즈</span>
# <span class="text--title">브리치X씨샵인더룸 BEST 15%쿠폰 셔츠/팬츠/가디건<!-- --> </span>
# <strong class="text--price_seller">14,600</strong>
# <strong class="text--price_original">48,600</strong>
# <span class="text">브리치-brich</span>
# <span class="text--title">쿠폰15% 원피스/블라우스/여름니트/가디건 빅사이즈<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">메이킹유</span>
# <span class="text--title">심리스 스포츠 브라탑 4종기획세트/노라인팬티 5종<!-- --> </span>
# <strong class="text--price_seller">13,500</strong>
# <strong class="text--price_original">45,000</strong>
# <span class="text">이너리즘</span>
# <span class="text--title">모카썸 15%썸머 티셔츠/원피스/1+1/루즈핏<!-- --> </span>
# <strong class="text--price_seller">6,900</strong>
# <strong class="text--price_original">23,000</strong>
# <span class="text">모카썸</span>
# <span class="text--title">15%할인쿠폰 마르조 오나라pick 썸머 페스티벌~<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">제이에프글로벌</span>
# <span class="text--title">남성 여성 반팔 순면 무지 티셔츠 오버핏 빅사이즈<!-- --> </span>
# <strong class="text--price_seller">3,900</strong>
# <strong class="text--price_original">13,000</strong>
# <span class="text">로드스타-루키스</span>
# <span class="text--title">성진 패션 원피스/팬츠/블라우스<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">32,900</strong>
# <span class="text">성진패션</span>
# <span class="text--title">투투 여름신상 린넨/배기/슬랙스/청바지/반바지 5XL<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">투투22</span>
# <span class="text--title">15%쿠폰 걸스데일리 빅사이즈 롱 원피스/티셔츠/팬츠<!-- --> </span>
# <strong class="text--price_seller">15,900</strong>
# <strong class="text--price_original">53,000</strong>
# <span class="text">걸스데일리</span>
# <span class="text--title">시원한 아이스 쿨 바지 세트/파자마/원피스<!-- --> </span>
# <strong class="text--price_seller">5,900</strong>
# <strong class="text--price_original">19,600</strong>
# <span class="text">모스트맘</span>
# <span class="text--title">티메이 블라우스 티셔츠 맨투맨<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">32,900</strong>
# <span class="text">Dk무역</span>
# <span class="text--title">시크루즈/15%/단하루/롱원피스/SET아이템/빅사이즈<!-- --> </span>
# <strong class="text--price_seller">11,900</strong>
# <strong class="text--price_original">39,600</strong>
# <span class="text">시크루즈</span>
# <span class="text--title">캔마트 SUMMER 신상 15%쿠폰할인 티셔츠/팬츠 外<!-- --> </span>
# <strong class="text--price_seller">16,500</strong>
# <strong class="text--price_original">55,000</strong>
# None
# <span class="text--title">빅사이즈 홈쇼핑 린넨블라우스4종/반팔티셔츠/팬츠<!-- --> </span>
# <strong class="text--price_seller">19,900</strong>
# <strong class="text--price_original">66,000</strong>
# <span class="text">리베레츠</span>
# <span class="text--title">시크폭스 여름신상/티셔츠/팬츠/1+1/원피스/린넨<!-- --> </span>
# <strong class="text--price_seller">13,900</strong>
# <strong class="text--price_original">46,300</strong>
# <span class="text">시크폭스</span>
# <span class="text--title">홈쇼핑 여름신상SALE 블라우스/원피스/티셔츠/팬츠 外<!-- --> </span>
# <strong class="text--price_seller">14,900</strong>
# <strong class="text--price_original">49,600</strong>
# <span class="text">건원무역</span>
# <span class="text--title">쉬블림로브 15%쿠폰 균일가 블라우스 셔츠 상하세트<!-- --> </span>
# <strong class="text--price_seller">8,900</strong>
# <strong class="text--price_original">29,600</strong>
# <span class="text">쉬블림로브</span>
# <span class="text--title">패션풀 여름신상 베스트/니트/원피스<!-- --> </span>
# <strong class="text--price_seller">14,900</strong>
# <strong class="text--price_original">49,500</strong>
# <span class="text">패션풀</span>
# <span class="text--title">다온샵 신상 15%쿠폰 빅사이즈/데님/슬랙스/반바지<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">다온샵.</span>
# <span class="text--title">브리치X바이미쓰리 BEST 15%쿠폰 셔츠/팬츠/원피스<!-- --> </span>
# <strong class="text--price_seller">7,900</strong>
# <strong class="text--price_original">26,300</strong>
# <span class="text">브리치-brich</span>
# <span class="text--title">15%쿠폰 여성반팔티 여자티셔츠 빅사이즈여성의류 롱<!-- --> </span>
# <strong class="text--price_seller">7,500</strong>
# <strong class="text--price_original">25,000</strong>
# <span class="text">사라걸스</span>
# <span class="text--title">남성/여성 3부~9부 파자마 잠옷바지 커플잠옷 국산 면<!-- --> </span>
# <strong class="text--price_seller">6,900</strong>
# <strong class="text--price_original">23,000</strong>
# <span class="text">한스속옷</span>
# <span class="text--title">여성팬티5매/여자/여성/속옷/미디/맥시/위생/삼각/면<!-- --> </span>
# <strong class="text--price_seller">6,900</strong>
# <strong class="text--price_original">23,000</strong>
# <span class="text">한스속옷</span>
# <span class="text--title">15%쿠폰/데이데이 여름신상 블라우스/원피스/팬츠<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">dayday-데이데이</span>
# <span class="text--title">이너리즘 심리스 브라탑 라이트 4종세트/노라인팬티<!-- --> </span>
# <strong class="text--price_seller">12,500</strong>
# <strong class="text--price_original">41,600</strong>
# <span class="text">이너리즘</span>
# <span class="text--title">썸머패션 15%할인 롱 티셔츠 후드티 반팔티 빅사이즈<!-- --> </span>
# <strong class="text--price_seller">6,900</strong>
# <strong class="text--price_original">23,000</strong>
# <span class="text">이프지</span>
# <span class="text--title">티탁 15%쿠폰 특가/세트/맨투맨/원피스/롱티셔츠<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">주식회사티탁</span>
# <span class="text--title">BNX 탱커스 ~70% 미리준비하는 여름신상<!-- --> </span>
# <strong class="text--price_seller">24,000</strong>
# <strong class="text--price_original">80,000</strong>
# <span class="text">BNX_TANKUS</span>
# <span class="text--title">트렌드15% 블루레이스 2021 여름신상OPEN<!-- --> </span>
# <strong class="text--price_seller">15,200</strong>
# <strong class="text--price_original">50,600</strong>
# <span class="text">istockmall_4CUS</span>
# <span class="text--title">A~F컵 브라/노와이어/빅사이즈/브라/여성팬티<!-- --> </span>
# <strong class="text--price_seller">3,900</strong>
# <strong class="text--price_original">13,000</strong>
# <span class="text">한스속옷</span>
# <span class="text--title">전국민15%쿠폰 여름NEW 빅사이즈/롱원피스/데님/4XL~<!-- --> </span>
# <strong class="text--price_seller">17,400</strong>
# <strong class="text--price_original">58,000</strong>
# <span class="text">스웨덴세탁소-</span>
# <span class="text--title">런닝5매/남성/남자/여성/여자/아동/조끼/반팔/속옷/면<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">한스속옷</span>
# <span class="text--title">쏭스타일15% 신상추가.원피스.빅사이즈.롱티.<!-- --> </span>
# <strong class="text--price_seller">7,900</strong>
# <strong class="text--price_original">26,300</strong>
# <span class="text">(주)쏭스타일</span>
# <span class="text--title">단비샵/봄신상/원피스/블라우스/자켓/청바지/반바지<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">DANBISHOP1</span>
# <span class="text--title">15%쿠폰/여름빅세일/2장이상구입시 팬티사은품/무배<!-- --> </span>
# <strong class="text--price_seller">8,900</strong>
# <strong class="text--price_original">22,300</strong>
# <span class="text">factiomall</span>
# <span class="text--title">브라썸/브라팬티세트 ABCD컵/왕뽕/빅사이즈/여성속옷<!-- --> </span>
# <strong class="text--price_seller">10,900</strong>
# <strong class="text--price_original">36,300</strong>
# <span class="text">파란언더웨어</span>
# <span class="text--title">달리샵 여름신상 빅사이즈 베스트 티셔츠/원피스/팬츠<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">달리샵1</span>
# <span class="text--title">15%쿠폰 홈쇼핑 빅사이즈 티 8종세트/남성반팔티/팬츠<!-- --> </span>
# <strong class="text--price_seller">29,900</strong>
# <strong class="text--price_original">99,000</strong>
# <span class="text">리베레츠</span>
# <span class="text--title">1+1+1/3장세트/쿨티셔츠/쿨론/여자/남자/무지/반팔티<!-- --> </span>
# <strong class="text--price_seller">14,900</strong>
# None
# <span class="text">어반티</span>
# <span class="text--title">16수 오버핏 남성 여성 반팔 무지 티셔츠 빅사이즈<!-- --> </span>
# <strong class="text--price_seller">10,900</strong>
# <strong class="text--price_original">36,300</strong>
# <span class="text">로드스타-루키스</span>
# <span class="text--title">기능성 사계절 에어로쿨 남성런닝 여성런닝 모음전<!-- --> </span>
# <strong class="text--price_seller">2,900</strong>
# None
# <span class="text">필인티모</span>
# <span class="text--title">시스터 여름신상 15% 빅사이즈/롱원피스/롱티/세트<!-- --> </span>
# <strong class="text--price_seller">6,900</strong>
# <strong class="text--price_original">23,000</strong>
# <span class="text">케이엠컴퍼니01</span>
# <span class="text--title">비너스외 노와이어브라 여자 여성 속옷 세트 브래지어<!-- --> </span>
# <strong class="text--price_seller">9,900</strong>
# <strong class="text--price_original">33,000</strong>
# <span class="text">란제리아샵</span>
# <span class="text--title">최대80~여성 반팔 티셔츠 여자 조거 청바지 빅사이즈<!-- --> </span>
# <strong class="text--price_seller">13,600</strong>
# None
# <span class="text">엘리번스</span>
# <span class="text--title">글램공감/브라1+팬티2/속옷세트/A~D컵/빅사이즈/속옷<!-- --> </span>
# <strong class="text--price_seller">10,900</strong>
# <strong class="text--price_original">36,300</strong>
# <span class="text">버블돌2</span>
# <span class="text--title">17%쿠폰 여름 클리어런스 데일리 티셔츠/팬츠 外<!-- --> </span>
# <strong class="text--price_seller">8,900</strong>
# <strong class="text--price_original">29,600</strong>
# <span class="text">SOUP</span>
# <span class="text--title">여름신상 여자청바지/와이드/부츠컷/일자/스키니<!-- --> </span>
# <strong class="text--price_seller">17,900</strong>
# None
# <span class="text">지기젠</span>
# <span class="text--title">5장세트 심리스 노라인 메쉬팬티 여자팬티 여성팬티 쿨<!-- --> </span>
# <strong class="text--price_seller">9,500</strong>
# <strong class="text--price_original">31,600</strong>
# <span class="text">이너리즘</span>
# <span class="text--title">DCOVERS/디커버스/반팔티/티셔츠/여성/남자/빅사이즈<!-- --> </span>
# <strong class="text--price_seller">7,500</strong>
# None
# <span class="text">AM-PM</span>
# <span class="text--title">올리비아로렌 시즌off인기템 티셔츠/팬츠 17%<!-- --> </span>
# <strong class="text--price_seller">16,900</strong>
# <strong class="text--price_original">56,300</strong>
# <span class="text">올리비아로렌</span>
# <span class="text--title">아놀드파마15% 남녀 블라우스 냉감티 원피스 골프웨어<!-- --> </span>
# <strong class="text--price_seller">7,900</strong>
# <strong class="text--price_original">26,300</strong>
# <span class="text">코리타</span>
# <span class="text--title">패션라인 여름블라우스 원피스/자켓/티셔츠/빅사이즈<!-- --> </span>
# <strong class="text--price_seller">12,900</strong>
# <strong class="text--price_original">43,000</strong>
# <span class="text">패션라인11</span>
# <span class="text--title">빅사이즈 쿨바지 여름 직업복 밴딩 여자 남성 일 바지<!-- --> </span>
# <strong class="text--price_seller">4,900</strong>
# None
# <span class="text">YONWOO88</span>
# <span class="text--title">9900원~ 로델리 여름원피스 블라우스 핫팬츠<!-- --> </span>
# <strong class="text--price_seller">12,900</strong>
# <strong class="text--price_original">36,000</strong>
# <span class="text">로델리</span>
# <span class="text--title">여름티여성반팔티흰색면티7부티셔츠라운드티흰티반팔<!-- --> </span>
# <strong class="text--price_seller">8,900</strong>
# None
# <span class="text">미씨룩</span>
# <span class="text--title"> 블랙야크  20SS 남성 여름기능성바지 U애슬리팬츠-1<!-- --> </span>
# <strong class="text--price_seller">37,730</strong>
# <strong class="text--price_original">49,000</strong>
# <span class="text">롯데백화점2관</span>

# %%
import pandas as pd

print(title, len(title))
print(price_sales, len(price_sales))
print(price_ori, len(price_ori))
print(company, len(company))

title1 = pd.Series(title)
price_sales1 = pd.Series(price_sales)
price_ori1 = pd.Series(price_ori)
company_name = pd.Series(company)
#%% 
dat = pd.DataFrame({ "title" : title , 
                   "price_sales" : price_sales, 
                   "price_origin" : price_ori,
                   "company_name" : company_name }, columns=['title','price_sales','price_origin', "company_name"] )
dat

dat.to_csv("company_info1.csv", index=False, encoding="utf-8")  # MAC 유저
dat.to_csv("company_info2.csv", index=False, encoding="EUCKR")  # Window EXCEL 한글 볼 때
# Out:
# ['다온샵 신상 15%쿠폰 빅사이즈/데님/슬랙스/반바지 ', '달리샵 여름신상 베스트 티셔츠/원피스/팬츠/스커트 ', '15%쿠폰/여름빅세일/2장이상구입시 팬티사은품/무배 ', '김여사봄신상 베스트 베이직 티셔츠/팬츠 균일가 20종 ', '16수 오버핏 남성 여성 반팔 무지 티셔츠 빅사이즈 ', '15%쿠폰 데이뮤즈 원피스/자켓/가디건/바지/블라우스 ', '달리샵 여름신상 빅사이즈 베스트 티셔츠/원피스/팬츠 ', '15%할인쿠폰 마르조 오나라pick 썸머 페스티벌~ ', 'EnC 봄여름 블라우스/원피스/팬츠 외 최대25%쿠폰 ', '단아하고 여성스러운 플라워 자수 블라우스 ', '티탁 15%쿠폰 특가/세트/맨투맨/원피스/롱티셔츠 ', '여름 오픈특가 블라우스/원피스/티셔츠외 ', '전국민15%쿠폰 여름NEW 빅사이즈/롱원피스/데님/4XL~ ', ' 헬리꽁땡  로즈 원피스 ', '여름 최신 핫 트렌드 신상템 특가 ', '15%쿠폰/데이데이 여름신상 블라우스/원피스/팬츠 ', '패션페스타20% 여성 반팔티셔츠 여자 빅사이즈 티셔츠 ', '(색상 검정) 비비안 유발타아즈50D/여성용/숙녀/무지 ', '빅사이즈 라운드 골지 티셔츠 니트느낌 오버핏 5XL까지 ', ' TAG ME 태그미 플리츠 셋업 3종 세트 ', '15% 쿠폰/데이데이 여름신상 블라우스/티셔츠/원피스 ', '드고떼 코튼 100 티블라우스 4종 ', ' Humming 허밍by 현영  린넨 블랜디드 셔츠형 블라우스 3종 ', '오리지날리 라운지웨어 원피스 2종 ', ' 런칭가 79000원  크레송CRESSON 21S/S 아트웍 블라우스 2종 ', '드고떼 코튼 100 티블라우스 4종 + 4종 ', '골지 핀턱 노와이어 브라탑 밴딩 브라렛 ', '골지 레이스 브라 팬티 세트 ', '요가 스포츠 노와이어 브라렛 ', '디즈니 아이스 쿨바지 V21 남성/여성/커플/조거팬츠 ', '디즈니 쿨 반팔세트 V21 남성/여성/커플/잠옷/홈웨어 ', '네모 팬티 사각 심리스 노라인 슬림 누디 자체제작 ', '15%쿠폰할인 메이시스 여름 루즈핏 원피스 블라우스 ', '수맘 여름 신상입고 15%쿠폰 면 홈웨어 잠옷 세트 ', '시크루즈/15%/단하루/티셔츠/박스티/팬츠/빅사이즈 ', '런닝 2500원/남자/남성/여자/여성/아동/쿨/조끼/인견 ', '엄마옷로즈맘 여름신상60종 인견 5060중년여성의류 ', '15%쿠폰 반팔티 운동복 티셔츠 롱티 원피스 빅사이즈 ', '15%중복쿠폰/쿨레깅스/쿨팬츠/원피스/7부/빅사이즈4XL ', '(15%쿠폰)애플힙 쿨링팬츠 빅사이즈 4XL 슬랙스/8부 ', '15%쿠폰 루즈델리 여름신상 롱원피스/빅사이즈/루즈핏 ', '모노시크/15%/티셔츠/신상/데일리/루즈핏/빅사이즈/ ', '15%쿠폰가/XXL까지/빅사이즈/하객룩원피스 ', '15%쿠폰 데이뮤즈 원피스/자켓/가디건/바지/블라우스 ', '브리치X씨샵인더룸 BEST 15%쿠폰 셔츠/팬츠/가디건 ', '쿠폰15% 원피스/블라우스/여름니트/가디건 빅사이즈 ', '심리스 스포츠 브라탑 4종기획세트/노라인팬티 5종 ', '모카썸 15%썸머 티셔츠/원피스/1+1/루즈핏 ', '15%할인쿠폰 마르조 오나라pick 썸머 페스티벌~ ', '남성 여성 반팔 순면 무지 티셔츠 오버핏 빅사이즈 ', '성진 패션 원피스/팬츠/블라우스 ', '투투 여름신상 린넨/배기/슬랙스/청바지/반바지 5XL ', '15%쿠폰 걸스데일리 빅사이즈 롱 원피스/티셔츠/팬츠 ', '시원한 아이스 쿨 바지 세트/파자마/원피스 ', '티메이 블라우스 티셔츠 맨투맨 ', '시크루즈/15%/단하루/롱원피스/SET아이템/빅사이즈 ', '캔마트 SUMMER 신상 15%쿠폰할인 티셔츠/팬츠 外 ', '빅사이즈 홈쇼핑 린넨블라우스4종/반팔티셔츠/팬츠 ', '시크폭스 여름신상/티셔츠/팬츠/1+1/원피스/린넨 ', '홈쇼핑 여름신상SALE 블라우스/원피스/티셔츠/팬츠 外 ', '쉬블림로브 15%쿠폰 균일가 블라우스 셔츠 상하세트 ', '패션풀 여름신상 베스트/니트/원피스 ', '다온샵 신상 15%쿠폰 빅사이즈/데님/슬랙스/반바지 ', '브리치X바이미쓰리 BEST 15%쿠폰 셔츠/팬츠/원피스 ', '15%쿠폰 여성반팔티 여자티셔츠 빅사이즈여성의류 롱 ', '남성/여성 3부~9부 파자마 잠옷바지 커플잠옷 국산 면 ', '여성팬티5매/여자/여성/속옷/미디/맥시/위생/삼각/면 ', '15%쿠폰/데이데이 여름신상 블라우스/원피스/팬츠 ', '이너리즘 심리스 브라탑 라이트 4종세트/노라인팬티 ', '썸머패션 15%할인 롱 티셔츠 후드티 반팔티 빅사이즈 ', '티탁 15%쿠폰 특가/세트/맨투맨/원피스/롱티셔츠 ', 'BNX 탱커스 ~70% 미리준비하는 여름신상 ', '트렌드15% 블루레이스 2021 여름신상OPEN ', 'A~F컵 브라/노와이어/빅사이즈/브라/여성팬티 ', '전국민15%쿠폰 여름NEW 빅사이즈/롱원피스/데님/4XL~ ', '런닝5매/남성/남자/여성/여자/아동/조끼/반팔/속옷/면 ', '쏭스타일15% 신상추가.원피스.빅사이즈.롱티. ', '단비샵/봄신상/원피스/블라우스/자켓/청바지/반바지 ', '15%쿠폰/여름빅세일/2장이상구입시 팬티사은품/무배 ', '브라썸/브라팬티세트 ABCD컵/왕뽕/빅사이즈/여성속옷 ', '달리샵 여름신상 빅사이즈 베스트 티셔츠/원피스/팬츠 ', '15%쿠폰 홈쇼핑 빅사이즈 티 8종세트/남성반팔티/팬츠 ', '1+1+1/3장세트/쿨티셔츠/쿨론/여자/남자/무지/반팔티 ', '16수 오버핏 남성 여성 반팔 무지 티셔츠 빅사이즈 ', '기능성 사계절 에어로쿨 남성런닝 여성런닝 모음전 ', '시스터 여름신상 15% 빅사이즈/롱원피스/롱티/세트 ', '비너스외 노와이어브라 여자 여성 속옷 세트 브래지어 ', '최대80~여성 반팔 티셔츠 여자 조거 청바지 빅사이즈 ', '글램공감/브라1+팬티2/속옷세트/A~D컵/빅사이즈/속옷 ', '17%쿠폰 여름 클리어런스 데일리 티셔츠/팬츠 外 ', '여름신상 여자청바지/와이드/부츠컷/일자/스키니 ', '5장세트 심리스 노라인 메쉬팬티 여자팬티 여성팬티 쿨 ', 'DCOVERS/디커버스/반팔티/티셔츠/여성/남자/빅사이즈 ', '올리비아로렌 시즌off인기템 티셔츠/팬츠 17% ', '아놀드파마15% 남녀 블라우스 냉감티 원피스 골프웨어 ', '패션라인 여름블라우스 원피스/자켓/티셔츠/빅사이즈 ', '빅사이즈 쿨바지 여름 직업복 밴딩 여자 남성 일 바지 ', '9900원~ 로델리 여름원피스 블라우스 핫팬츠 ', '여름티여성반팔티흰색면티7부티셔츠라운드티흰티반팔 ', ' 블랙야크  20SS 남성 여름기능성바지 U애슬리팬츠-1 '] 100
# ['9,900', '9,900', '8,900', '16,050', '10,900', '9,900', '9,900', '9,900', '29,000', '27,040', '9,900', '9,900', '17,400', '49,800', '19,900', '9,900', '7,900', '8,490', '14,900', '38,900', '9,900', '29,900', '49,000', '39,900', '59,000', '39,900', '5,000', '10,000', '5,000', '9,900', '14,900', '5,900', '9,900', '5,900', '6,900', '2,900', '12,900', '9,900', '6,900', '6,900', '12,900', '7,900', '29,800', '9,900', '14,600', '9,900', '13,500', '6,900', '9,900', '3,900', '9,900', '9,900', '15,900', '5,900', '9,900', '11,900', '16,500', '19,900', '13,900', '14,900', '8,900', '14,900', '9,900', '7,900', '7,500', '6,900', '6,900', '9,900', '12,500', '6,900', '9,900', '24,000', '15,200', '3,900', '17,400', '9,900', '7,900', '9,900', '8,900', '10,900', '9,900', '29,900', '14,900', '10,900', '2,900', '6,900', '9,900', '13,600', '10,900', '8,900', '17,900', '9,500', '7,500', '16,900', '7,900', '12,900', '4,900', '12,900', '8,900', '37,730'] 100
# ['33,000', '33,000', '22,300', '16,900', '36,300', '33,000', '33,000', '33,000', '96,660', '29,400', '33,000', '33,000', '58,000', '', '66,300', '33,000', '', '', '', '39,900', '33,000', '', '', '', '', '', '', '', '', '', '', '', '33,000', '19,600', '23,000', '9,600', '43,000', '33,000', '23,000', '22,900', '43,000', '26,300', '99,300', '33,000', '48,600', '33,000', '45,000', '23,000', '33,000', '13,000', '32,900', '33,000', '53,000', '19,600', '32,900', '39,600', '55,000', '66,000', '46,300', '49,600', '29,600', '49,500', '33,000', '26,300', '25,000', '23,000', '23,000', '33,000', '41,600', '23,000', '33,000', '80,000', '50,600', '13,000', '58,000', '33,000', '26,300', '33,000', '22,300', '36,300', '33,000', '99,000', '', '36,300', '', '23,000', '33,000', '', '36,300', '29,600', '', '31,600', '', '56,300', '26,300', '43,000', '', '36,000', '', '49,000'] 100
# ['다온샵.', '달리샵1', 'factiomall', '김여사샵', '로드스타-루키스', '데이뮤즈', '달리샵1', '제이에프글로벌', 'EnC(이앤씨)', 'sellerbay1', '주식회사티탁', 'able.h', '스웨덴세탁소-', '롯데홈쇼핑', 'able.h', 'dayday-데이데이', '사라걸스', '엑스포할인몰', '위러쉬', '최우수판매자', 'dayday-데이데이', '최우수판매자', '최우수판매자', '최우수판매자', '최우수판매자', '최우수판매자', '스마일배송', '스마일배송', '스마일배송', '스마일배송', '스마일배송', '스마일배송', '메이시스1', '(수맘)', '시크루즈', '한스속옷', '엄마옷로즈맘', '뷰티플러스1168', 'VIVIDGLAM_', '애플힙20', '루즈델리', 'monochic01', '시크라인', '데이뮤즈', '브리치-brich', '메이킹유', '이너리즘', '모카썸', '제이에프글로벌', '로드스타-루키스', '성진패션', '투투22', '걸스데일리', '모스트맘', 'Dk무역', '시크루즈', '스마일배송', '리베레츠', '시크폭스', '건원무역', '쉬블림로브', '패션풀', '다온샵.', '브리치-brich', '사라걸스', '한스속옷', '한스속옷', 'dayday-데이데이', '이너리즘', '이프지', '주식회사티탁', 'BNX_TANKUS', 'istockmall_4CUS', '한스속옷', '스웨덴세탁소-', '한스속옷', '(주)쏭스타일', 'DANBISHOP1', 'factiomall', '파란언더웨어', '달리샵1', '리베레츠', '어반티', '로드스타-루키스', '필인티모', '케이엠컴퍼니01', '란제리아샵', '엘리번스', '버블돌2', 'SOUP', '지기젠', '이너리즘', 'AM-PM', '올리비아로렌', '코리타', '패션라인11', 'YONWOO88', '로델리', '미씨룩', '롯데백화점2관'] 100
