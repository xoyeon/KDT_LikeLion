# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
basic_url = "https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=187322&target=after"

# %%
url1 = "https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=187322&target=after"
page = urlopen(url1)
soup = BeautifulSoup(page, "html.parser")

comment_all = soup.find_all('td', class_='title')
comment_all
# Out:
# [<td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=187322">크루엘라</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>자연스럽게 흘러갔음. 매우 재미있었음.
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('bare****', 'pjC+yx4N2cVXCumxj41rscFbCwntvSrePwUi5wUxNzQ=', '자연스럽게 흘러갔음. 매우 재미있었음.', '17577109', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>,
#  <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=187322">크루엘라</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>크루엘라 2번을 봤어요 정말 가슴이 후련해요
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('opt5****', 'Tlj6hfoX97NXo+udw5J+EF7Vtrs9sR7OxjZJXcUhj2k=', '크루엘라 2번을 봤어요 정말 가슴이 후련해요', '17577104', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>,
#  <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=187322">크루엘라</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>
#  <a class="report" href="#" onclick="report('phy4****', 'XIzuyOFLt0164L8VMbY5axmUFHD6IwZIiG69slyXMuo=', '', '17577098', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>,
#  <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=187322">크루엘라</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>최고 너무 재밌게 봤어요
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('seoi****', 'rSGX/drliC/tbAPFhDp7WLY1U7+GGOekqAv05s8gBEc=', '최고 너무 재밌게 봤어요', '17577074', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>,
#  <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=187322">크루엘라</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>그냥 존나 재밌음 보셈 ㄹㅇ
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('ifax****', 'JymrzpNpdvWQTVAqAkM+lSCSgSpl6eN+g4ILysZJ0FQ=', '그냥 존나 재밌음 보셈 ㄹㅇ ', '17577034', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>,
#  <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=187322">크루엘라</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>엠마 스톤이 연기를 정말 잘해요! 봐도 후회하지 않으실거예요!!
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('thom****', '3Nr0klMlmcNp1SXSTVJ2KZiXj8NliR7AkebRN04LLp8=', '엠마 스톤이 연기를 정말 잘해요! 봐도 후회하지 않으실거예요!!', '17577000', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>,
#  <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=187322">크루엘라</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:80%">별점 - 총 10점 중</span></span><em>8</em>
#  </div>
#  <br/>다 좋은대 CG가 조금 불안정한게 아쉽다 모든 퀄리티가 최상인대 디즈니의 이름값에는 조금 아쉬운 CG 였다
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('ffxi****', '1r3hmHQmw8kpdpo/hrHi8/BPWF4CAuLx7gi8ftALSlw=', '다 좋은대 CG가 조금 불안정한게 아쉽다 모든 퀄리티가 최상인대 디즈니의 이름값에는 조금 아쉬운 CG 였다', '17576988', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>,
#  <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=187322">크루엘라</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>이정도면 돈 아깝지 않은 영화
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('lghk****', 'mGEAx5CE7bcXZfo2uTp/rx46dsVLNt9auPIF3EMSlqY=', '이정도면 돈 아깝지 않은 영화', '17576966', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>,
#  <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=187322">크루엘라</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>진짜 개애재밌어요 꼭 보세요님들 진짜로... 개재밌어요 시즌 2가 기대되는 영화.. 개봉하자마자 달려갈 예정
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('cyoo****', 'V+DHOJnEQjtuDLPPk0QRl/j42OOcQLnDumcxNKJvlc8=', '진짜 개애재밌어요 꼭 보세요님들 진짜로... 개재밌어요 시즌 2가 기대되는 영화.. 개봉하자마자 달려갈 예정', '17576956', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>,
#  <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=187322">크루엘라</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>굳 넘나 재밌음 짱 엠마스톤 연기 대박이
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('aman****', 'J6atgJywcpDVeejfxTiYeDGK+GbpgPzfDnS6EJmA69w=', '굳 넘나 재밌음 짱 엠마스톤 연기 대박이', '17576903', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>]

# %%
list(comment_all[9].children)
# Out:
# ['\n',
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=187322">크루엘라</a>,
#  '\n',
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>,
#  '\n',
#  <br/>,
#  '굳 넘나 재밌음 짱 엠마스톤 연기 대박이 \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t',
#  <a class="report" href="#" onclick="report('aman****', 'J6atgJywcpDVeejfxTiYeDGK+GbpgPzfDnS6EJmA69w=', '굳 넘나 재밌음 짱 엠마스톤 연기 대박이', '17576903', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>,
#  '\n']

# %%
print(len(comment_all))
# Out:
# 10

# %%
temp = list(comment_all[5].children)
temp[6]
# Out:
# '엠마 스톤이 연기를 정말 잘해요! 봐도 후회하지 않으실거예요!! \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t'

# %%
temp = list(comment_all[1].children)
result = temp[6].strip()
result
# Out:
# '크루엘라 2번을 봤어요 정말 가슴이 후련해요'

# %%
cnt = 0
comments = []
for comment in comment_all:
    temp = list(comment.children)
    if len(temp) < 5:
        cnt = cnt + 1
        continue
    else:
        try:
            cnt = cnt + 1
            result = temp[6].strip()
            comments.append(result)
        except:
            print("error cnt count", cnt)
            
comments
# Out:
# ['자연스럽게 흘러갔음. 매우 재미있었음.',
#  '크루엘라 2번을 봤어요 정말 가슴이 후련해요',
#  '',
#  '최고 너무 재밌게 봤어요',
#  '그냥 존나 재밌음 보셈 ㄹㅇ',
#  '엠마 스톤이 연기를 정말 잘해요! 봐도 후회하지 않으실거예요!!',
#  '다 좋은대 CG가 조금 불안정한게 아쉽다 모든 퀄리티가 최상인대 디즈니의 이름값에는 조금 아쉬운 CG 였다',
#  '이정도면 돈 아깝지 않은 영화',
#  '진짜 개애재밌어요 꼭 보세요님들 진짜로... 개재밌어요 시즌 2가 기대되는 영화.. 개봉하자마자 달려갈 예정',
#  '굳 넘나 재밌음 짱 엠마스톤 연기 대박이']

# %%
comments = [ ]
cnt = 0
for i in range(1,8):
    url = basic_url + str(i)
    page = urlopen(url)
    soup = BeautifulSoup(page, "html.parser")

    comment_all = soup.find_all('td', class_='title')
    for comment in comment_all:
        temp= list(comment.children)
        if len(temp) < 5:
            cnt= cnt + 1
            print("len<5 case :",cnt)
            continue
        else:
            try:
                cnt= cnt + 1
                result = temp[6].strip()
                comments.append(result)
            except:
                cnt= cnt + 1
                print("len>=5 case ",cnt)
                print(temp)
print(len(comments))
print(comments)
print(cnt)
# Out:
# 70
# ['자연스럽게 흘러갔음. 매우 재미있었음.', '크루엘라 2번을 봤어요 정말 가슴이 후련해요', '', '최고 너무 재밌게 봤어요', '그냥 존나 재밌음 보셈 ㄹㅇ', '엠마 스톤이 연기를 정말 잘해요! 봐도 후회하지 않으실거예요!!', '다 좋은대 CG가 조금 불안정한게 아쉽다 모든 퀄리티가 최상인대 디즈니의 이름값에는 조금 아쉬운 CG 였다', '이정도면 돈 아깝지 않은 영화', '진짜 개애재밌어요 꼭 보세요님들 진짜로... 개재밌어요 시즌 2가 기대되는 영화.. 개봉하자마자 달려갈 예정', '굳 넘나 재밌음 짱 엠마스톤 연기 대박이', '자연스럽게 흘러갔음. 매우 재미있었음.', '크루엘라 2번을 봤어요 정말 가슴이 후련해요', '', '최고 너무 재밌게 봤어요', '그냥 존나 재밌음 보셈 ㄹㅇ', '엠마 스톤이 연기를 정말 잘해요! 봐도 후회하지 않으실거예요!!', '다 좋은대 CG가 조금 불안정한게 아쉽다 모든 퀄리티가 최상인대 디즈니의 이름값에는 조금 아쉬운 CG 였다', '이정도면 돈 아깝지 않은 영화', '진짜 개애재밌어요 꼭 보세요님들 진짜로... 개재밌어요 시즌 2가 기대되는 영화.. 개봉하자마자 달려갈 예정', '굳 넘나 재밌음 짱 엠마스톤 연기 대박이', '자연스럽게 흘러갔음. 매우 재미있었음.', '크루엘라 2번을 봤어요 정말 가슴이 후련해요', '', '최고 너무 재밌게 봤어요', '그냥 존나 재밌음 보셈 ㄹㅇ', '엠마 스톤이 연기를 정말 잘해요! 봐도 후회하지 않으실거예요!!', '다 좋은대 CG가 조금 불안정한게 아쉽다 모든 퀄리티가 최상인대 디즈니의 이름값에는 조금 아쉬운 CG 였다', '이정도면 돈 아깝지 않은 영화', '진짜 개애재밌어요 꼭 보세요님들 진짜로... 개재밌어요 시즌 2가 기대되는 영화.. 개봉하자마자 달려갈 예정', '굳 넘나 재밌음 짱 엠마스톤 연기 대박이', '자연스럽게 흘러갔음. 매우 재미있었음.', '크루엘라 2번을 봤어요 정말 가슴이 후련해요', '', '최고 너무 재밌게 봤어요', '그냥 존나 재밌음 보셈 ㄹㅇ', '엠마 스톤이 연기를 정말 잘해요! 봐도 후회하지 않으실거예요!!', '다 좋은대 CG가 조금 불안정한게 아쉽다 모든 퀄리티가 최상인대 디즈니의 이름값에는 조금 아쉬운 CG 였다', '이정도면 돈 아깝지 않은 영화', '진짜 개애재밌어요 꼭 보세요님들 진짜로... 개재밌어요 시즌 2가 기대되는 영화.. 개봉하자마자 달려갈 예정', '굳 넘나 재밌음 짱 엠마스톤 연기 대박이', '자연스럽게 흘러갔음. 매우 재미있었음.', '크루엘라 2번을 봤어요 정말 가슴이 후련해요', '', '최고 너무 재밌게 봤어요', '그냥 존나 재밌음 보셈 ㄹㅇ', '엠마 스톤이 연기를 정말 잘해요! 봐도 후회하지 않으실거예요!!', '다 좋은대 CG가 조금 불안정한게 아쉽다 모든 퀄리티가 최상인대 디즈니의 이름값에는 조금 아쉬운 CG 였다', '이정도면 돈 아깝지 않은 영화', '진짜 개애재밌어요 꼭 보세요님들 진짜로... 개재밌어요 시즌 2가 기대되는 영화.. 개봉하자마자 달려갈 예정', '굳 넘나 재밌음 짱 엠마스톤 연기 대박이', '자연스럽게 흘러갔음. 매우 재미있었음.', '크루엘라 2번을 봤어요 정말 가슴이 후련해요', '', '최고 너무 재밌게 봤어요', '그냥 존나 재밌음 보셈 ㄹㅇ', '엠마 스톤이 연기를 정말 잘해요! 봐도 후회하지 않으실거예요!!', '다 좋은대 CG가 조금 불안정한게 아쉽다 모든 퀄리티가 최상인대 디즈니의 이름값에는 조금 아쉬운 CG 였다', '이정도면 돈 아깝지 않은 영화', '진짜 개애재밌어요 꼭 보세요님들 진짜로... 개재밌어요 시즌 2가 기대되는 영화.. 개봉하자마자 달려갈 예정', '굳 넘나 재밌음 짱 엠마스톤 연기 대박이', '자연스럽게 흘러갔음. 매우 재미있었음.', '크루엘라 2번을 봤어요 정말 가슴이 후련해요', '', '최고 너무 재밌게 봤어요', '그냥 존나 재밌음 보셈 ㄹㅇ', '엠마 스톤이 연기를 정말 잘해요! 봐도 후회하지 않으실거예요!!', '다 좋은대 CG가 조금 불안정한게 아쉽다 모든 퀄리티가 최상인대 디즈니의 이름값에는 조금 아쉬운 CG 였다', '이정도면 돈 아깝지 않은 영화', '진짜 개애재밌어요 꼭 보세요님들 진짜로... 개재밌어요 시즌 2가 기대되는 영화.. 개봉하자마자 달려갈 예정', '굳 넘나 재밌음 짱 엠마스톤 연기 대박이']
# 70

# %%
import pandas as pd

# %%
dict_doc = {"text" : comments}
doc = pd.DataFrame(dict_doc)

# %%
doc.to_csv("크루엘라리뷰.csv", index = False)

# %%
from wordcloud import WordCloud, STOPWORDS

import numpy as np
from PIL import Image

# %%
f = open("크루엘라리뷰.csv", encoding="utf-8")
text = f.read()
f.close()

# %%
from matplotlib import rc
rc('font', family='NanumGothic')

# %%
# %matplotlib inline
from wordcloud import WordCloud
wcloud = WordCloud('./data/D2Coding.ttf', max_words=1000, relative_scaling = 0.2).generate(text)

import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
plt.imshow(wcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
